# %% [markdown]
# <a href="https://colab.research.google.com/github/xErbacaro/foooocus/blob/main/Foooooocus_IA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.12.2
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --preset anime --share
# Out:
# ...
# /content
# fatal: destination path 'Fooocus' already exists and is not an empty directory.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--preset', 'anime', '--share']
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Fooocus version: 2.1.865
# Loaded preset: /content/Fooocus/presets/anime.json
# Downloading: "https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/animaPencilXL_v100.safetensors" to /content/Fooocus/models/checkpoints/animaPencilXL_v100.safetensors
#
# 100% 6.46G/6.46G [00:30<00:00, 230MB/s]
# Running on local URL:  http://127.0.0.1:7865
# Total VRAM 15102 MB, total RAM 12979 MB
# Set vram state to: NORMAL_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# ...
